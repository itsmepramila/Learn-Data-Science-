# %%
# !pip install openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
employee=pd.read_excel("employee-dept-table.xlsx", sheet_name='employee')
employee
# Out:
#   EmployeeID FirstName  LastName  DepartmentID
# 0      a23e1     Alice   Johnson           101
# 1      c4b1e       Bob     Smith           102
# 2      d56a9     Carol  Williams           101
# 3      f87c3     David     Brown           103
# 4      e29d7     Emily     Jones           102
# 5      d66p4       Dev     Kumar           106

# %%
department=pd.read_excel("employee-dept-table.xlsx", sheet_name='dept')
department
# Out:
#    DepartmentID DepartmentName       Location
# 0           101             HR       New York
# 1           102    Engineering  San Francisco
# 2           103      Marketing    Los Angeles
# 3           104             AI        Florida

# %% [markdown]
# <img src="https://datagy.io/wp-content/uploads/2021/12/Different-Merge-Types-Available-in-Pandas-683x1024.png">

# %%
pd.merge(left=employee, right=department, on='DepartmentID', how='inner')
# Out:
#   EmployeeID FirstName  LastName  DepartmentID DepartmentName       Location
# 0      a23e1     Alice   Johnson           101             HR       New York
# 1      d56a9     Carol  Williams           101             HR       New York
# 2      c4b1e       Bob     Smith           102    Engineering  San Francisco
# 3      e29d7     Emily     Jones           102    Engineering  San Francisco
# 4      f87c3     David     Brown           103      Marketing    Los Angeles

# %%
pd.merge(left=employee, right=department, on='DepartmentID', how='inner')
# Out:
#   EmployeeID FirstName  LastName  DepartmentID DepartmentName       Location
# 0      a23e1     Alice   Johnson           101             HR       New York
# 1      d56a9     Carol  Williams           101             HR       New York
# 2      c4b1e       Bob     Smith           102    Engineering  San Francisco
# 3      e29d7     Emily     Jones           102    Engineering  San Francisco
# 4      f87c3     David     Brown           103      Marketing    Los Angeles

# %%
pd.merge(left=department, right=employee, on='DepartmentID', how='inner')
# Out:
#    DepartmentID DepartmentName       Location EmployeeID FirstName  LastName
# 0           101             HR       New York      a23e1     Alice   Johnson
# 1           101             HR       New York      d56a9     Carol  Williams
# 2           102    Engineering  San Francisco      c4b1e       Bob     Smith
# 3           102    Engineering  San Francisco      e29d7     Emily     Jones
# 4           103      Marketing    Los Angeles      f87c3     David     Brown

# %%
pd.merge(left=department, right=employee, on='DepartmentID', how='outer')
# Out:
#    DepartmentID DepartmentName       Location EmployeeID FirstName  LastName
# 0           101             HR       New York      a23e1     Alice   Johnson
# 1           101             HR       New York      d56a9     Carol  Williams
# 2           102    Engineering  San Francisco      c4b1e       Bob     Smith
# 3           102    Engineering  San Francisco      e29d7     Emily     Jones
# 4           103      Marketing    Los Angeles      f87c3     David     Brown
# 5           104             AI        Florida        NaN       NaN       NaN
# 6           106            NaN            NaN      d66p4       Dev     Kumar
